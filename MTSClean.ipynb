# %%
import pandas as pd
import matplotlib.pyplot as plt

# 从IDF数据中读取一段长度为100的数据
idf = pd.read_csv('./datasets/idf.csv')[['U3_HNC10CT111', 'U3_HNC10CT112', 'U3_HNC10CT113']][:100]

# 画图
idf.plot(subplots=True, figsize=(5, 3))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)
